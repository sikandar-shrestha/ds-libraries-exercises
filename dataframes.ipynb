# %% [markdown]
# # Exercises
#
# Do your work for this exercise in a python script or a jupyter notebook with the name dataframes.py or dataframes.ipynb.
#
# For several of the following exercises, you'll need to load several datasets using the pydataset library. (If you get an error when trying to run the import below, use pip to install the pydataset package.)
#
# ### from pydataset import data
#
#
# When the instructions say to load a dataset, you can pass the name of the dataset as a string to the data function to load the dataset. You can also view the documentation for the data set by passing the show_doc keyword argument.
#
#
# ## view the documentation for the dataset :---
# ### data('mpg', show_doc=True)
#
# ## load the dataset and store it in a variable :---
# ### mpg = data('mpg')
#
# All the datasets loaded from the pydataset library will be pandas dataframes.

# %% [markdown]
# ## Q1) Copy the code from the lesson to create a dataframe full of student grades

# %%
import pandas as pd
import numpy as np

np.random.seed(123)

students = ['Sally', 'Jane', 'Suzie', 'Billy', 'Ada', 'John', 'Thomas',
            'Marie', 'Albert', 'Richard', 'Isaac', 'Alan']

# randomly generate scores for each student for each subject
# note that all the values need to have the same length here
math_grades = np.random.randint(low=60, high=100, size=len(students))
english_grades = np.random.randint(low=60, high=100, size=len(students))
reading_grades = np.random.randint(low=60, high=100, size=len(students))

df = pd.DataFrame({'name': students,
                   'math': math_grades,
                   'english': english_grades,
                   'reading': reading_grades})

# %%
df

# %% [markdown]
# ## a) Create a column named passing_english that indicates whether each student has a passing grade in english.

# %%
# (it converts into pandas series,so we can use vectorized operation

df['passing_english']= df['english'] >=70  
df.head()

# %% [markdown]
# # b) Sort the english grades by the passing_english column. How are duplicates handled?

# %%
# by default ascending= True
df.sort_values('passing_english')

# %% [markdown]
# ## c)Sort the english grades first by passing_english and then by student name.
#
# All the students that are failing english should be first, and within the students
# that are failing english they should be ordered alphabetically.
#
# The same should be true for the students passing english.
#
# (Hint: you can pass a list to the .sort_values method)

# %%
df.sort_values(['passing_english','name'])

# %% [markdown]
# # d) Sort the english grades first by passing_english, and then by the actual english grade, similar to how we did in the last step.

# %%
df.sort_values(['passing_english','english'])

# %% [markdown]
# ## e) Calculate each students overall grade and add it as a column on the dataframe.
#
# ## The overall grade is the average of the math, english, and reading grades.

# %%
df['Overall Grade'] = round(df[['math', 'english', 'reading']].mean(axis=1).astype(float))
df

# %%
df['Overall Grade'].mean() # here axis=o i.e. row-wise mean i.e. allover

# %% [markdown]
# For several of the following exercises, you'll need to load several datasets using the pydataset library. (If you get an error when trying to run the import below, use pip to install the pydataset package.)
#
# ### from pydataset import data
#
#
# When the instructions say to load a dataset, you can pass the name of the dataset as a string to the data function to load the dataset. You can also view the documentation for the data set by passing the show_doc keyword argument.
#
#
# ## view the documentation for the dataset :---
# ### data('mpg', show_doc=True)
#
# ## load the dataset and store it in a variable :---
# ### mpg = data('mpg')
#
# All the datasets loaded from the pydataset library will be pandas dataframes.
#
#
# ## Q2) Load the mpg dataset. Read the documentation for the dataset and use it for the following questions:
#
# How many rows and columns are there?
#
# What are the data types of each column?
#
# Summarize the dataframe with .info and .describe
#
# Rename the cty column to city.
#
# Rename the hwy column to highway.
#
# Do any cars have better city mileage than highway mileage?
#
# Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.
#
# Which car (or cars) has the highest mileage difference?
#
# Which compact class car has the lowest highway mileage? The best?
#
# Create a column named average_mileage that is the mean of the city and highway mileage.
#
# Which dodge car has the best average mileage? The worst?

# %%
from pydataset import data

# %%
data('mpg',show_doc=True)
# Out:
# mpg
#
# PyDataset Documentation (adopted from R Documentation. The displayed examples are in R)
#
# ## Fuel economy data from 1999 and 2008 for 38 popular models of car
#
# ### Description
#
# This dataset contains a subset of the fuel economy data that the EPA makes
# available on http://fueleconomy.gov. It contains only models which had a new
# release every year between 1999 and 2008 - this was used as a proxy for the
# popularity of the car.
#
# ### Usage
#
#     data(mpg)
#
# ### Format
#
# A data frame with 234 rows and 11 variables
#
# ### Details
#
#   * manufacturer.
#
#   * model.
#
#   * displ. engine displacement, in litres
#
#   * year.
#
#   * cyl. number of cylinders
#
#   * trans. type of transmission
#
#   * drv. f = front-wheel drive, r = rear wheel drive, 4 = 4wd
#
#   * cty. city miles per gallon
#
#   * hwy. highway miles per gallon
#
#   * fl.
#
#   * class.

# %%
df=data('mpg')

# %%
df.head(5)
# Out:
#   manufacturer model  displ  year  cyl       trans drv  cty  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f   18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f   21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f   20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f   21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f   16   26  p  compact

# %% [markdown]
# ## How many rows and columns are there?

# %%
df.shape
# Out:
# (234, 11)

# %% [markdown]
# ## What are the data types of each column?

# %%
df.dtypes
# Out:
# manufacturer     object
# model            object
# displ           float64
# year              int64
# cyl               int64
# trans            object
# drv              object
# cty               int64
# hwy               int64
# fl               object
# class            object
# dtype: object

# %% [markdown]
# ## Summarize the dataframe with .info and .describe

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 234 entries, 1 to 234
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   manufacturer  234 non-null    object
#  1   model         234 non-null    object
#  2   displ         234 non-null    float64
#  3   year          234 non-null    int64
#  4   cyl           234 non-null    int64
#  5   trans         234 non-null    object
#  6   drv           234 non-null    object
#  7   cty           234 non-null    int64
#  8   hwy           234 non-null    int64
#  9   fl            234 non-null    object
#  10  class         234 non-null    object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 21.9+ KB

# %%
df.describe()
# Out:
#             displ         year         cyl         cty         hwy
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# ## Rename the cty column to city.

# %%
df.rename(columns={'cty':'city'}, inplace=True) 

# or df = df.rename(columns={'cty':'city'}) 

## make it equavalent to df or inplace=True
# otherwise its gonna go to the original dataframe

# %%
df.head(5)
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f    21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16   26  p  compact

# %% [markdown]
# ## Rename the hwy column to highway.

# %%
df.rename(columns={'hwy':'highway'}, inplace=True)
df.head(5)
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class
# 1  compact
# 2  compact
# 3  compact
# 4  compact
# 5  compact

# %% [markdown]
# ## Do any cars have better city mileage than highway mileage?

# %%
(df.city >df.highway).sum()
# Out:
# 0

# %%
# another way
(df.city>df.highway).any()
# Out:
# False

# %% [markdown]
#  ## Create a column named mileage_difference this column should contain the difference between highway and city mileage for each car.

# %%
df['mileage_difference']=df.highway-df.city

# %%
df.head(5)
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class  mileage_differenc  mileage_difference
# 1  compact                 11                  11
# 2  compact                  8                   8
# 3  compact                 11                  11
# 4  compact                  9                   9
# 5  compact                 10                  10

# %% [markdown]
# ## Which car (or cars) has the highest mileage difference?

# %%
df['mileage_difference'].max()
# Out:
# 12

# %%
df.sort_values(by='mileage_difference',ascending=False)
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  city  \
# 107        honda              civic    1.8  2008    4    auto(l5)   f    24
# 223   volkswagen         new beetle    1.9  1999    4    auto(l4)   f    29
# 1           audi                 a4    1.8  1999    4    auto(l5)   f    18
# 229   volkswagen             passat    1.8  1999    4    auto(l5)   f    18
# 36     chevrolet             malibu    3.5  2008    6    auto(l4)   f    18
# ..           ...                ...    ...   ...  ...         ...  ..   ...
# 80          ford       explorer 4wd    4.0  1999    6    auto(l5)   4    14
# 138      mercury    mountaineer 4wd    4.0  1999    6    auto(l5)   4    14
# 177       toyota        4runner 4wd    3.4  1999    6  manual(m5)   4    15
# 152       nissan     pathfinder 4wd    3.3  1999    6  manual(m5)   4    15
# 204       toyota  toyota tacoma 4wd    3.4  1999    6  manual(m5)   4    15
#
# ...

# %%
df.sort_values(by='mileage_difference').head(2)
# Out:
#     manufacturer              model  displ  year  cyl       trans drv  city  \
# 204       toyota  toyota tacoma 4wd    3.4  1999    6  manual(m5)   4    15
# 177       toyota        4runner 4wd    3.4  1999    6  manual(m5)   4    15
#
#      highway fl   class  mileage_differenc  mileage_difference
# 204       17  r  pickup                  2                   2
# 177       17  r     suv                  2                   2

# %% [markdown]
# ## Which compact class car has the lowest highway mileage? The best?

# %%
# 1st way : highest highway mileage

df[(df['highway']==df['highway'].max() ) & (df['class']=='compact')]
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  city  highway fl  \
# 213   volkswagen  jetta    1.9  1999    4  manual(m5)   f    33       44  d
#
#        class  mileage_differenc  mileage_difference
# 213  compact                 11                  11

# %%
# 2nd way : highest highway mileage

df[df['class']=='compact'].sort_values(by='highway', ascending=False).head(1)
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  city  highway fl  \
# 213   volkswagen  jetta    1.9  1999    4  manual(m5)   f    33       44  d
#
#        class  mileage_differenc  mileage_difference
# 213  compact                 11                  11

# %%
# 1st way : lowest highway mileage

df[(df['highway']==df['highway'].min() ) & (df['class']=='compact')]
# Out:
# Empty DataFrame
# Columns: [manufacturer, model, displ, year, cyl, trans, drv, city, highway, fl, class, mileage_differenc, mileage_difference]
# Index: []

# %%
# 2nd way : lowest highway mileage

df[df['class']=='compact'].sort_values(by='highway', ascending=False).tail(1)
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  city  highway fl  \
# 220   volkswagen  jetta    2.8  1999    6  auto(l4)   f    16       23  r
#
#        class  mileage_differenc  mileage_difference
# 220  compact                  7                   7

# %%
# 3rd way (boolean masks):
df.head(5)
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class  mileage_differenc  mileage_difference
# 1  compact                 11                  11
# 2  compact                  8                   8
# 3  compact                 11                  11
# 4  compact                  9                   9
# 5  compact                 10                  10

# %%
df['class'].value_counts()
# Out:
# class
# suv           62
# compact       47
# midsize       41
# subcompact    35
# pickup        33
# minivan       11
# 2seater        5
# Name: count, dtype: int64

# %%
#boolean masks
df['class'] == 'compact'
# Out:
# 1       True
# 2       True
# 3       True
# 4       True
# 5       True
#        ...
# 230    False
# 231    False
# 232    False
# 233    False
# 234    False
# Name: class, Length: 234, dtype: bool

# %%
#boolean masks will filter out values 
df [df['class'] == 'compact'].head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class  mileage_differenc  mileage_difference
# 1  compact                 11                  11
# 2  compact                  8                   8
# 3  compact                 11                  11
# 4  compact                  9                   9
# 5  compact                 10                  10

# %%
# lowest
df [df['class'] == 'compact'].sort_values('highway').head(1)
# Out:
#     manufacturer  model  displ  year  cyl     trans drv  city  highway fl  \
# 220   volkswagen  jetta    2.8  1999    6  auto(l4)   f    16       23  r
#
#        class  mileage_differenc  mileage_difference
# 220  compact                  7                   7

# %%
# highest
df [df['class'] == 'compact'].sort_values('highway').tail(1)
# Out:
#     manufacturer  model  displ  year  cyl       trans drv  city  highway fl  \
# 213   volkswagen  jetta    1.9  1999    4  manual(m5)   f    33       44  d
#
#        class  mileage_differenc  mileage_difference
# 213  compact                 11                  11

# %% [markdown]
# ## Create a column named average_mileage that is the mean of the city and highway mileage

# %%
df['average_mileage']=df[['city', 'highway']].mean(axis=1)
df.head(5)
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class  mileage_differenc  mileage_difference  average_mileage
# 1  compact                 11                  11             23.5
# 2  compact                  8                   8             25.0
# 3  compact                 11                  11             25.5
# 4  compact                  9                   9             25.5
# 5  compact                 10                  10             21.0

# %% [markdown]
# ## Which dodge car has the best average mileage? The worst?

# %%
# lowest average mileage


df[df['manufacturer']=='dodge'].sort_values(by='average_mileage').head(1)
# Out:
#    manufacturer                model  displ  year  cyl       trans drv  city  \
# 70        dodge  ram 1500 pickup 4wd    4.7  2008    8  manual(m6)   4     9
#
#     highway fl   class  mileage_differenc  mileage_difference  average_mileage
# 70       12  e  pickup                  3                   3             10.5

# %%
# highest average mileage

df[df['manufacturer']=='dodge'].sort_values(by='average_mileage',ascending=True).tail(1)
# Out:
#    manufacturer        model  displ  year  cyl     trans drv  city  highway  \
# 38        dodge  caravan 2wd    2.4  1999    4  auto(l3)   f    18       24
#
#    fl    class  mileage_differenc  mileage_difference  average_mileage
# 38  r  minivan                  6                   6             21.0

# %% [markdown]
# ## Q3) Load the Mammals dataset. Read the documentation for it, and use the data to answer these questions:
#
#
#
# - How many rows and columns are there?
#
# - What are the data types?
#
# - Summarize the dataframe with .info and .describe
#
# - What is the the weight of the fastest animal?
#
# - What is the overal percentage of specials?
#
# - How many animals are hoppers that are above the median speed? What percentage is this?

# %%
from pydataset import data

# %%
data('Mammals', show_doc=True)

# %%
df=data('Mammals')
df.head()

# %% [markdown]
# ##  How many rows and columns are there?

# %%
df.shape

# %% [markdown]
# ## What are the data types?

# %%
df.dtypes

# %% [markdown]
# ## Summarize the dataframe with .info and .describe

# %%
df.info()

# %%
df.describe()

# %%
df.describe(include='all')

# %% [markdown]
# ## What is the the weight of the fastest animal?

# %%
df.sort_values(by='speed',ascending=False).head(1)

# %%
df.sort_values(by='speed',ascending=False).head(1).weight

# %% [markdown]
# ## What is the overal percentage of specials?

# %%
# What is the overal percentage of specials?

len(df[df['specials']==True])/len(df)*100

# %% [markdown]
# ## How many animals are hoppers that are above the median speed? What percentage is this?

# %%
df.speed.median()

# %%
 len(df[(df['hoppers']== True) &(df['speed']>df.speed.median())] )/len(df)*100

# %%
# Another ways:
#only hoppers
hoppers = df[df.hoppers]
hoppers

# %%
#seeing all the hoppers with speeds greater than the median
hoppers [(hoppers.speed) > (df.speed.median())]

# %%
#counting the number of hoppers with speeds greater than the median
numb_hoppers = ((hoppers.speed) > (df.speed.median())).sum()
numb_hoppers

# %%
#this is everyone
len(df)

# %%
#diving to get the percentage
numb_hoppers / len(df)*100
