# %% [markdown]
# # Exercises I
#
# Run python -m pip install pymysql from your terminal to install pymysql.
#
# Create a notebook or python script named advanced_dataframes to do your work in for these exercises.
#
#
#
# 1.Run python -m pip install pymysql from your terminal to install the mysql client (any folder is fine)
#
# 2.cd into your exercises folder for this module and run echo env.py >> .gitignore
#
# 3.Create a function named get_db_url.
#   It should accept a username, hostname, password, and database name and return a url connection string formatted     like in the example at the start of this lesson.
#
#
# 4.Use your function to obtain a connection to the employees database.
#
# 5.Once you have successfully run a query:
#
#     a. Intentionally make a typo in the database url. What kind of error message do you see?
#
#     b. Intentionally make an error in your SQL query. What does the error message look like?
#
# 6.Read the employees and titles tables into two separate DataFrames.
#
# 7.How many rows and columns do you have in each DataFrame? Is that what you expected?
#
# 8.Display the summary statistics for each DataFrame.
#
# 9.How many unique titles are in the titles DataFrame?
#
# 10.What is the oldest date in the to_date column?
#
# 11.What is the most recent date in the to_date column?

# %% [markdown]
# ## Q1).Run python -m pip install pymysql from your terminal to install the mysql client (any folder is fine)
#
# ## done!

# %% [markdown]
# ### Q2)cd into your exercises folder for this module and run echo env.py >> .gitignore
#
# Done!

# %% [markdown]
# ### Q3.Create a function named get_db_url. It should accept a username, hostname, password, and database name and return a url connection string formatted like in the example at the start of this lesson.

# %%
import env

# %%
def get_db_url(hostname, username, password,database):
        return f"mysql+pymysql://{username}:{password}@{hostname}/{database}"

# %% [markdown]
# ### Q4.Use your function to obtain a connection to the employees database.

# %%
url=get_db_url(env.hostname,env.username,env.password,'employees')

# url not leaving it printed out

# %% [markdown]
# ### Q5)Once you have successfully run a query:

# %%
import pandas as pd

# %%
pd.read_sql('select * from employees limit 5', url)
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %% [markdown]
# ### Q5)a. Intentionally make a typo in the database url. What kind of error message do you see?

# %%
 url=get_db_url(env.hostname,env.username,env.password,'employeekkkks')

# %%
 # pd.read_sql('select * from employees limit 5',url)

# %% [markdown]
# ### Q5) b.b. Intentionally make an error in your SQL query. What does the error message look like?

# %%
url=get_db_url(env.hostname,env.username,env.password,'employees')

# %%
# pd.read_sql('select * from emp titles limit 5', url)

# %% [markdown]
# ### Q6.Read the employees and titles tables into two separate DataFrames.

# %%
df_emp = pd.read_sql('select * from employees', url)

# %%
df_emp.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
df_title = pd.read_sql('select * from titles', url)

# %%
df_title.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %% [markdown]
# ### Q7.How many rows and columns do you have in each DataFrame? Is that what you expected?

# %%
df_emp.shape
# Out:
# (300024, 6)

# %%
df_title.shape
# Out:
# (443308, 4)

# %% [markdown]
# ### Q8.Display the summary statistics for each DataFrame.

# %%
df_emp.describe()
# Out:
#               emp_no
# count  300024.000000
# mean   253321.763392
# std    161828.235540
# min     10001.000000
# 25%     85006.750000
# 50%    249987.500000
# 75%    424993.250000
# max    499999.000000

# %%
df_title.describe()
# Out:
#               emp_no
# count  443308.000000
# mean   253075.034430
# std    161853.292613
# min     10001.000000
# 25%     84855.750000
# 50%    249847.500000
# 75%    424891.250000
# max    499999.000000

# %%
df_emp.describe(include='all')
# Out:
#                emp_no  birth_date first_name last_name  gender   hire_date
# count   300024.000000      300024     300024    300024  300024      300024
# unique            NaN        4750       1275      1637       2        5434
# top               NaN  1952-03-08     Shahab      Baba       M  1985-06-20
# freq              NaN          95        295       226  179973         132
# mean    253321.763392         NaN        NaN       NaN     NaN         NaN
# std     161828.235540         NaN        NaN       NaN     NaN         NaN
# min      10001.000000         NaN        NaN       NaN     NaN         NaN
# 25%      85006.750000         NaN        NaN       NaN     NaN         NaN
# 50%     249987.500000         NaN        NaN       NaN     NaN         NaN
# 75%     424993.250000         NaN        NaN       NaN     NaN         NaN
# max     499999.000000         NaN        NaN       NaN     NaN         NaN

# %%
df_title.describe(include='all')
# Out:
#                emp_no     title   from_date     to_date
# count   443308.000000    443308      443308      443308
# unique            NaN         7        6393        5888
# top               NaN  Engineer  1998-10-25  9999-01-01
# freq              NaN    115003         132      240124
# mean    253075.034430       NaN         NaN         NaN
# std     161853.292613       NaN         NaN         NaN
# min      10001.000000       NaN         NaN         NaN
# 25%      84855.750000       NaN         NaN         NaN
# 50%     249847.500000       NaN         NaN         NaN
# 75%     424891.250000       NaN         NaN         NaN
# max     499999.000000       NaN         NaN         NaN

# %% [markdown]
# ### Q9.How many unique titles are in the titles DataFrame?

# %%
df_title
# Out:
#         emp_no            title   from_date     to_date
# 0        10001  Senior Engineer  1986-06-26  9999-01-01
# 1        10002            Staff  1996-08-03  9999-01-01
# 2        10003  Senior Engineer  1995-12-03  9999-01-01
# 3        10004         Engineer  1986-12-01  1995-12-01
# 4        10004  Senior Engineer  1995-12-01  9999-01-01
# ...        ...              ...         ...         ...
# 443303  499997         Engineer  1987-08-30  1992-08-29
# 443304  499997  Senior Engineer  1992-08-29  9999-01-01
# 443305  499998     Senior Staff  1998-12-27  9999-01-01
# 443306  499998            Staff  1993-12-27  1998-12-27
# 443307  499999         Engineer  1997-11-30  9999-01-01
#
# [443308 rows x 4 columns]

# %%
df_title.title.unique()
# Out:
# array(['Senior Engineer', 'Staff', 'Engineer', 'Senior Staff',
#        'Assistant Engineer', 'Technique Leader', 'Manager'], dtype=object)

# %%
df_title.title.nunique()
# Out:
# 7

# %%
# 2nd way
len(df_title.title.unique())
# Out:
# 7

# %% [markdown]
# ### Q10.What is the oldest date in the to_date column?

# %%
# old date
df_title.sort_values('to_date').head(1)
# Out:
#        emp_no     title   from_date     to_date
# 16064   20869  Engineer  1985-02-17  1985-03-01

# %%
# 2nd way
df_title.to_date.min()
# Out:
# datetime.date(1985, 3, 1)

# %% [markdown]
# ### Q11.What is the recent date in the to_date column?

# %%
# recent date
df_title.sort_values('to_date').tail(1)
# Out:
#         emp_no     title   from_date     to_date
# 443307  499999  Engineer  1997-11-30  9999-01-01

# %%
df_title.to_date.max()
# Out:
# datetime.date(9999, 1, 1)

# %% [markdown]
# # Exercises II
#
# Copy the users and roles DataFrames from the examples above.
#
# What is the result of using a right join on the DataFrames?
#
# What is the result of using an outer join on the DataFrames?
#
# What happens if you drop the foreign keys from the DataFrames and try to merge them?
#
# Load the mpg dataset from PyDataset.
#
# Output and read the documentation for the mpg dataset.
#
# How many rows and columns are in the dataset?
#
# Check out your column names and perform any cleanup you may want on them.
#
# Display the summary statistics for the dataset.
#
# How many different manufacturers are there?
#
# How many different models are there?
#
# Create a column named mileage_difference like you did in the DataFrames exercises; this column should contain the difference between highway and city mileage for each car.
#
# Create a column named average_mileage like you did in the DataFrames exercises; this is the mean of the city and highway mileage.
#
# Create a new column on the mpg dataset named is_automatic that holds boolean values denoting whether the car has an automatic transmission.
#
# Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?
#
# Do automatic or manual cars have better miles per gallon?

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Copy the users and roles DataFrames from the examples above.

# %%
# Create the users DataFrame.

users = pd.DataFrame({
    'id': [1, 2, 3, 4, 5, 6],
    'name': ['bob', 'joe', 'sally', 'adam', 'jane', 'mike'],
    'role_id': [1, 2, 3, 3, np.nan, np.nan]
})
users
# Out:
#    id   name  role_id
# 0   1    bob      1.0
# 1   2    joe      2.0
# 2   3  sally      3.0
# 3   4   adam      3.0
# 4   5   jane      NaN
# 5   6   mike      NaN

# %%
# Create the roles DataFrame

roles = pd.DataFrame({
    'id': [1, 2, 3, 4],
    'name': ['admin', 'author', 'reviewer', 'commenter']
})
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %% [markdown]
# ### What is the result of using a right join on the DataFrames?

# %%
pd.merge(users,roles,how='right', left_on='role_id',right_on='id')
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0     1      admin
# 1   2.0    joe      2.0     2     author
# 2   3.0  sally      3.0     3   reviewer
# 3   4.0   adam      3.0     3   reviewer
# 4   NaN    NaN      NaN     4  commenter

# %% [markdown]
# ### What is the result of using an outer join on the DataFrames?

# %%
pd.merge(users,roles,how='outer', left_on='role_id',right_on='id',)
# Out:
#    id_x name_x  role_id  id_y     name_y
# 0   1.0    bob      1.0   1.0      admin
# 1   2.0    joe      2.0   2.0     author
# 2   3.0  sally      3.0   3.0   reviewer
# 3   4.0   adam      3.0   3.0   reviewer
# 4   5.0   jane      NaN   NaN        NaN
# 5   6.0   mike      NaN   NaN        NaN
# 6   NaN    NaN      NaN   4.0  commenter

# %% [markdown]
# ### What happens if you drop the foreign keys from the DataFrames and try to merge them?

# %%
users = users.drop(columns='role_id')

# %%
users
# Out:
#    id   name
# 0   1    bob
# 1   2    joe
# 2   3  sally
# 3   4   adam
# 4   5   jane
# 5   6   mike

# %%
roles
# Out:
#    id       name
# 0   1      admin
# 1   2     author
# 2   3   reviewer
# 3   4  commenter

# %%
pd.merge(users,roles,how='inner',on='id')
# Out:
#    id name_x     name_y
# 0   1    bob      admin
# 1   2    joe     author
# 2   3  sally   reviewer
# 3   4   adam  commenter

# %%
pd.merge(users,roles,how='outer')
# Out:
#    id       name
# 0   1        bob
# 1   2        joe
# 2   3      sally
# 3   4       adam
# 4   5       jane
# 5   6       mike
# 6   1      admin
# 7   2     author
# 8   3   reviewer
# 9   4  commenter

# %%
pd.merge(users,roles,how='outer',on='id')
# Out:
#    id name_x     name_y
# 0   1    bob      admin
# 1   2    joe     author
# 2   3  sally   reviewer
# 3   4   adam  commenter
# 4   5   jane        NaN
# 5   6   mike        NaN

# %% [markdown]
# ### Load the mpg dataset from PyDataset.

# %%
from pydataset import data
df=data('mpg')
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %% [markdown]
# ### Output and read the documentation for the mpg dataset.

# %%
# data('mpg', show_doc=True)

# %% [markdown]
# ### How many rows and columns are in the dataset?

# %%
df.shape
# Out:
# (234, 11)

# %% [markdown]
# ### Check out your column names and perform any cleanup you may want on them.

# %%
df
# Out:
#     manufacturer   model  displ  year  cyl       trans drv  cty  hwy fl  \
# 1           audi      a4    1.8  1999    4    auto(l5)   f   18   29  p
# 2           audi      a4    1.8  1999    4  manual(m5)   f   21   29  p
# 3           audi      a4    2.0  2008    4  manual(m6)   f   20   31  p
# 4           audi      a4    2.0  2008    4    auto(av)   f   21   30  p
# 5           audi      a4    2.8  1999    6    auto(l5)   f   16   26  p
# ..           ...     ...    ...   ...  ...         ...  ..  ...  ... ..
# 230   volkswagen  passat    2.0  2008    4    auto(s6)   f   19   28  p
# 231   volkswagen  passat    2.0  2008    4  manual(m6)   f   21   29  p
# 232   volkswagen  passat    2.8  1999    6    auto(l5)   f   16   26  p
# 233   volkswagen  passat    2.8  1999    6  manual(m5)   f   18   26  p
# 234   volkswagen  passat    3.6  2008    6    auto(s6)   f   17   26  p
#
#        class
# 1    compact
# 2    compact
# 3    compact
# 4    compact
# 5    compact
# ..       ...
# ...

# %%
df.rename(columns={'cty':'city'}, inplace= True)
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  hwy fl    class
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18   29  p  compact
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21   29  p  compact
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20   31  p  compact
# 4         audi    a4    2.0  2008    4    auto(av)   f    21   30  p  compact
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16   26  p  compact

# %%
df.rename(columns={'hwy':'highway'},inplace= True)
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class
# 1  compact
# 2  compact
# 3  compact
# 4  compact
# 5  compact

# %% [markdown]
# ### Display the summary statistics for the dataset.

# %%
df.describe()
# Out:
#             displ         year         cyl        city     highway
# count  234.000000   234.000000  234.000000  234.000000  234.000000
# mean     3.471795  2003.500000    5.888889   16.858974   23.440171
# std      1.291959     4.509646    1.611534    4.255946    5.954643
# min      1.600000  1999.000000    4.000000    9.000000   12.000000
# 25%      2.400000  1999.000000    4.000000   14.000000   18.000000
# 50%      3.300000  2003.500000    6.000000   17.000000   24.000000
# 75%      4.600000  2008.000000    8.000000   19.000000   27.000000
# max      7.000000  2008.000000    8.000000   35.000000   44.000000

# %% [markdown]
# ###  How many different manufacturers are there?

# %%
df.manufacturer.unique()
# Out:
# array(['audi', 'chevrolet', 'dodge', 'ford', 'honda', 'hyundai', 'jeep',
#        'land rover', 'lincoln', 'mercury', 'nissan', 'pontiac', 'subaru',
#        'toyota', 'volkswagen'], dtype=object)

# %%
df.manufacturer.nunique()
# Out:
# 15

# %%
len(df.manufacturer.unique())
# Out:
# 15

# %% [markdown]
# ### How many different models are there?

# %%
df.model.nunique()
# Out:
# 38

# %%
df.model.unique()
# Out:
# array(['a4', 'a4 quattro', 'a6 quattro', 'c1500 suburban 2wd', 'corvette',
#        'k1500 tahoe 4wd', 'malibu', 'caravan 2wd', 'dakota pickup 4wd',
#        'durango 4wd', 'ram 1500 pickup 4wd', 'expedition 2wd',
#        'explorer 4wd', 'f150 pickup 4wd', 'mustang', 'civic', 'sonata',
#        'tiburon', 'grand cherokee 4wd', 'range rover', 'navigator 2wd',
#        'mountaineer 4wd', 'altima', 'maxima', 'pathfinder 4wd',
#        'grand prix', 'forester awd', 'impreza awd', '4runner 4wd',
#        'camry', 'camry solara', 'corolla', 'land cruiser wagon 4wd',
#        'toyota tacoma 4wd', 'gti', 'jetta', 'new beetle', 'passat'],
#       dtype=object)

# %% [markdown]
# ### Create a column named mileage_difference like you did in the DataFrames exercises;
# ### this column should contain the difference between highway and city mileage for each car.

# %%
df['mileage_difference']=df.highway-df.city
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class  mileage_difference
# 1  compact                  11
# 2  compact                   8
# 3  compact                  11
# 4  compact                   9
# 5  compact                  10

# %% [markdown]
# ### Create a column named average_mileage like you did in the DataFrames exercises;
# ### this is the mean of the city and highway mileage.

# %%
df['average_mileage']=df[['city','highway']].mean(axis=1)
df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class  mileage_difference  average_mileage
# 1  compact                  11             23.5
# 2  compact                   8             25.0
# 3  compact                  11             25.5
# 4  compact                   9             25.5
# 5  compact                  10             21.0

# %% [markdown]
# ### Create a new column on the mpg dataset named is_automatic that holds boolean values denoting
# ### whether the car has an automatic transmission.

# %%
df.trans.unique()
# Out:
# array(['auto(l5)', 'manual(m5)', 'manual(m6)', 'auto(av)', 'auto(s6)',
#        'auto(l4)', 'auto(l3)', 'auto(l6)', 'auto(s5)', 'auto(s4)'],
#       dtype=object)

# %%
# 1st way

# df['is_automatic'] = df['trans'].str.contains('auto')
# df.head()

# %%
# 2nd way

df["is_automatic"] = np.where(df.trans.str.startswith('a'),True,False)

df.head()
# Out:
#   manufacturer model  displ  year  cyl       trans drv  city  highway fl  \
# 1         audi    a4    1.8  1999    4    auto(l5)   f    18       29  p
# 2         audi    a4    1.8  1999    4  manual(m5)   f    21       29  p
# 3         audi    a4    2.0  2008    4  manual(m6)   f    20       31  p
# 4         audi    a4    2.0  2008    4    auto(av)   f    21       30  p
# 5         audi    a4    2.8  1999    6    auto(l5)   f    16       26  p
#
#      class  mileage_difference  average_mileage  is_automatic
# 1  compact                  11             23.5          True
# 2  compact                   8             25.0         False
# 3  compact                  11             25.5         False
# 4  compact                   9             25.5          True
# 5  compact                  10             21.0          True

# %% [markdown]
# ### Using the mpg dataset, find out which which manufacturer has the best miles per gallon on average?

# %%
df[['manufacturer','average_mileage']].groupby('manufacturer').mean().round(1)\
.sort_values('average_mileage',ascending=False).head(1)
# Out:
#               average_mileage
# manufacturer
# honda                    28.5

# %%
#based on an interpretation of the question
df[['manufacturer','average_mileage']]\
.groupby('manufacturer').max().sort_values('average_mileage', ascending=False).head(1)
# Out:
#               average_mileage
# manufacturer
# volkswagen               39.5

# %% [markdown]
# ### Do automatic or manual cars have better miles per gallon?

# %%
df.groupby('is_automatic')['average_mileage'].mean()
# Out:
# is_automatic
# False    22.227273
# True     19.130573
# Name: average_mileage, dtype: float64

# %% [markdown]
# # Exercises III
#
# 1.Use your get_db_url function to help you explore the data from the chipotle database.
#
# 2.What is the total price for each order?
#
# 3.What are the most popular 3 items?
#
# 4.Which item has produced the most revenue?
#
# 5.Join the employees and titles DataFrames together.
#
# 6.For each title, find the hire date of the employee that was hired most recently with that title.
#
# 7.Write the code necessary to create a cross tabulation of the number of titles by department. (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code to perform the manipulations.)

# %%
# Q1.Use your get_db_url function to help you explore the data from the chipotle database.

url=get_db_url(env.hostname,env.username,env.password,'chipotle')
#url

# %%
df_chipo=pd.read_sql('select * from orders', url)
df_chipo.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#   item_price
# 0     $2.39
# 1     $3.39
# 2     $3.39
# 3     $2.39
# 4    $16.98

# %%
# Q2.What is the total price for each order?
df_chipo['item_price']=df_chipo['item_price'].str.strip('$').astype(float)
df_chipo
# Out:
#         id  order_id  quantity                              item_name  \
# 0        1         1         1           Chips and Fresh Tomato Salsa
# 1        2         1         1                                   Izze
# 2        3         1         1                       Nantucket Nectar
# 3        4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4        5         2         2                           Chicken Bowl
# ...    ...       ...       ...                                    ...
# 4617  4618      1833         1                          Steak Burrito
# 4618  4619      1833         1                          Steak Burrito
# 4619  4620      1834         1                     Chicken Salad Bowl
# 4620  4621      1834         1                     Chicken Salad Bowl
# 4621  4622      1834         1                     Chicken Salad Bowl
#
#                                                                      choice_description  \
# ...

# %%
df_chipo.groupby('order_id').item_price.sum()
# Out:
# order_id
# 1       11.56
# 2       16.98
# 3       12.67
# 4       21.00
# 5       13.70
#         ...
# 1830    23.00
# 1831    12.90
# 1832    13.20
# 1833    23.50
# 1834    28.75
# Name: item_price, Length: 1834, dtype: float64

# %%
# Q3.What are the most popular 3 items?
df_chipo.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#    item_price
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98

# %%
# 1st way
df_chipo.groupby('item_name').quantity.sum().nlargest(3)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Name: quantity, dtype: int64

# %%
#2nd way
df_chipo.groupby('item_name').sum()['quantity'].nlargest(3)
# Out:
# item_name
# Chicken Bowl           761
# Chicken Burrito        591
# Chips and Guacamole    506
# Name: quantity, dtype: int64

# %%
# Q4.Which item has produced the most revenue? 

df_chipo.head()
# Out:
#    id  order_id  quantity                              item_name  \
# 0   1         1         1           Chips and Fresh Tomato Salsa
# 1   2         1         1                                   Izze
# 2   3         1         1                       Nantucket Nectar
# 3   4         1         1  Chips and Tomatillo-Green Chili Salsa
# 4   5         2         2                           Chicken Bowl
#
#                                                            choice_description  \
# 0                                                                         nan
# 1                                                                [Clementine]
# 2                                                                     [Apple]
# 3                                                                         nan
# 4  [Tomatillo-Red Chili Salsa (Hot), [Black Beans, Rice, Cheese, Sour Cream]]
#
#    item_price
# 0        2.39
# 1        3.39
# 2        3.39
# 3        2.39
# 4       16.98

# %%
df_chipo.groupby('item_name').item_price.sum().nlargest(1)
# Out:
# item_name
# Chicken Bowl    7342.73
# Name: item_price, dtype: float64

# %%
# Q5.Join the employees and titles DataFrames together. 

url=get_db_url(env.hostname,env.username,env.password,'employees')

# %%
df_emp=pd.read_sql('select * from employees', url)
df_emp.head()
# Out:
#    emp_no  birth_date first_name last_name gender   hire_date
# 0   10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1   10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2   10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3   10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4   10005  1955-01-21    Kyoichi  Maliniak      M  1989-09-12

# %%
df_title=pd.read_sql('select * from titles', url)
df_title.head()
# Out:
#    emp_no            title   from_date     to_date
# 0   10001  Senior Engineer  1986-06-26  9999-01-01
# 1   10002            Staff  1996-08-03  9999-01-01
# 2   10003  Senior Engineer  1995-12-03  9999-01-01
# 3   10004         Engineer  1986-12-01  1995-12-01
# 4   10004  Senior Engineer  1995-12-01  9999-01-01

# %%
df_emp_tit=pd.merge(df_emp,df_title,how='inner', on='emp_no')
df_emp_tit
# Out:
#         emp_no  birth_date first_name last_name gender   hire_date  \
# 0        10001  1953-09-02     Georgi   Facello      M  1986-06-26
# 1        10002  1964-06-02    Bezalel    Simmel      F  1985-11-21
# 2        10003  1959-12-03      Parto   Bamford      M  1986-08-28
# 3        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# 4        10004  1954-05-01  Chirstian   Koblick      M  1986-12-01
# ...        ...         ...        ...       ...    ...         ...
# 443303  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443304  499997  1961-08-03    Berhard    Lenart      M  1986-04-21
# 443305  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443306  499998  1956-09-05   Patricia   Breugel      M  1993-10-13
# 443307  499999  1958-05-01     Sachin   Tsukuda      M  1997-11-30
#
#                   title   from_date     to_date
# 0       Senior Engineer  1986-06-26  9999-01-01
# 1                 Staff  1996-08-03  9999-01-01
# ...

# %%
df_emp_tit.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 443308 entries, 0 to 443307
# Data columns (total 9 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   emp_no      443308 non-null  int64
#  1   birth_date  443308 non-null  object
#  2   first_name  443308 non-null  object
#  3   last_name   443308 non-null  object
#  4   gender      443308 non-null  object
#  5   hire_date   443308 non-null  object
#  6   title       443308 non-null  object
#  7   from_date   443308 non-null  object
#  8   to_date     443308 non-null  object
# dtypes: int64(1), object(8)
# memory usage: 30.4+ MB

# %%
# Q6.For each title, find the hire date of the employee that was hired most recently with that title.
df_emp_tit.groupby('title').hire_date.max()
# Out:
# title
# Assistant Engineer   1999-12-24
# Engineer             2000-01-28
# Manager              1992-02-05
# Senior Engineer      2000-01-01
# Senior Staff         2000-01-13
# Staff                2000-01-12
# Technique Leader     1999-12-31
# Name: hire_date, dtype: datetime64[ns]

# %%
# Q7..Write the code necessary to create a cross tabulation of the number of titles by department. 
# (Hint: this will involve a combination of SQL code to pull the necessary data and python/pandas code 
# to perform the manipulations.)

df_depts=pd.read_sql('''
select *
from departments
join dept_emp
    using(dept_no)
join employees
    using(emp_no)
join titles
    using(emp_no)''',url)
df_depts.head()
# Out:
#    emp_no dept_no         dept_name   from_date     to_date  birth_date  \
# 0   10011    d009  Customer Service  1990-01-22  1996-11-09  1953-11-07
# 1   10038    d009  Customer Service  1989-09-20  9999-01-01  1960-07-20
# 2   10038    d009  Customer Service  1989-09-20  9999-01-01  1960-07-20
# 3   10049    d009  Customer Service  1992-05-04  9999-01-01  1961-04-24
# 4   10049    d009  Customer Service  1992-05-04  9999-01-01  1961-04-24
#
#   first_name last_name gender   hire_date         title   from_date  \
# 0       Mary     Sluis      F  1990-01-22         Staff  1990-01-22
# 1       Huan     Lortz      M  1989-09-20  Senior Staff  1996-09-20
# 2       Huan     Lortz      M  1989-09-20         Staff  1989-09-20
# 3      Basil    Tramer      F  1992-05-04  Senior Staff  2000-05-04
# 4      Basil    Tramer      F  1992-05-04         Staff  1992-05-04
#
#       to_date
# 0  1996-11-09
# 1  9999-01-01
# 2  1996-09-20
# 3  9999-01-01
# 4  2000-05-04

# %%
pd.crosstab(df_depts.title,df_depts.dept_name)
# Out:
# dept_name           Customer Service  Development  Finance  Human Resources  \
# title
# Assistant Engineer               298         7769        0                0
# Engineer                        2362        58135        0                0
# Manager                            4            2        2                2
# Senior Engineer                 2027        49326        0                0
# Senior Staff                   13925         1247    12139            12274
# Staff                          16150         1424    13929            14342
# Technique Leader                 309         7683        0                0
#
# dept_name           Marketing  Production  Quality Management  Research  Sales
# title
# Assistant Engineer          0        6445                1831       378      0
# Engineer                    0       49649               13852      2986      0
# Manager                     2           4                   4         2      2
# ...
